# %% [markdown]
# 1.Simple star pyramid
# *
# **
# ***
# ****
# *****
# 2.Reverse pyramid
# *****
# ****
# ***
# **
# *
# 3.Right aligned pyramid
#      *
#     **
#    ***
#   ****
#  *****
# 4.Left aliged pyramid
# 5.Full pyramid:
#
#     *
#    ***
#   *****
#  *******
# *********
# 6.Inverted pyramid
# 7.Use numbers in pyramid
# 1
# 12
# 123
# 1234
# 12345
#
# 8.Numbers center pyramid
#
#         1
#        121
#       12321
#      1234321
#     123454321

# %%
#3.Right aligned pyramid
#     *
#    **
#   ***
#  ****
# *****  

 #Spaces decresed
 #Stars incresed

# %%
n=5  # No of rows
for i in range(1,n+1): # range(1,5) -> 1,2,3,4,5 :Loop through 5 times
    print(" "*(n-i)+"*"*i)  #Print spaces and stars  " "*(n-i) -> spaces , "*"*i -> stars
# Out:
#     *
#    **
#   ***
#  ****
# *****
